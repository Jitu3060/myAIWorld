# %% [markdown]
# # Implementing a Variational Autoencoder (VAE) with TensorFlow for Image Generation Using the MNIST Dataset

# %% [markdown]
# ## Steps to perform
#
# '''
# Step 1: Import the Necessary Libraries
#
# Step 2: Load the MNIST Dataset
#
# Step 3: Set Hyperparameters
#
# Step 4: Define Model Architecture
#
# Step 5: Define the Sampling Function
#
# Step 6: Connect the Encoder and Decoder
#
# Step 7: Define the Loss Function and Compile the Model
#
# Step 8: Train the Model
#
# Step 9: Generate a Manifold of Digits
# '''

# %% [markdown]
# ### Step 1: Import the Necessary Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %% [markdown]
# ### Step 2: Load the MNIST Dataset

# %%
mnist = tf.keras.datasets.mnist
(x_train, _), (x_test, _) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# %% [markdown]
# ### Step 3: Set Hyperparameters
# ##### * Define the learning_rate, num_steps, and batch_size.
# ##### * learning_rate is the step size at each iteration while moving toward a minimum of a loss function.
# ##### * num_steps is the number of steps you want to train the model.
# ##### * batch_size is the number of samples that will be propagated through the network.

# %%
learning_rate = 0.001
num_steps = 100
batch_size = 64

# %% [markdown]
# ### Step 4: Define VAE Model Architecture including encoder, decoder along with loss function

# %%
latent_dim=2 # Latent space dimension

# Define encoder part
encoder_inputs = tf.keras.Input(shape=(28,28))
x = tf.keras.layers.Flatten()(encoder_inputs)
x = tf.keras.layers.Dense(512,activation='relu')(x)
z_mean = tf.keras.layers.Dense(latent_dim)(x)
z_log_var = tf.keras.layers.Dense(latent_dim)(x)

# Define Decoder Part
latent_inputs  = tf.keras.Input(shape=(latent_dim,))
x = tf.keras.layers.Dense(512,activation='relu')(latent_inputs)
x = tf.keras.layers.Dense(784,activation='sigmoid')(x)
decoder_outputs = tf.keras.layers.Reshape((28,28))(x)

# %% [markdown]
# ### Step 5: Define the Sampling Function

# %%
# Create a custom Keras layer for the sampling function used in the VAE.

class Sampling(tf.keras.layers.Layer):
    def call(self,inputs):
        z_mean,z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch,dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %% [markdown]
# ### Step 6: Connect the Encoder and the Decoder

# %% [markdown]
# '''
# Use keras functional API to connect the encoder and decoder parts of the VAE.encoder_outputs: The output of the Sampling layer, representing the latent variable 𝑧 z.
# encoder model: Combines the input layer, Dense layers, and Sampling layer into a complete encoder model. decoder model: Takes the latent variable 𝑧 z as input and outputs the reconstructed image. vae_outputs: The final output of the VAE model, which is the reconstructed image. vae model: Combines the encoder and decoder into a single model that takes an image as input, encodes it into the latent space, and decodes it back to reconstruct the original ima
# '''

# %%
encoder_outputs = Sampling()([z_mean, z_log_var])
encoder = tf.keras.Model(inputs=encoder_inputs, outputs=[z_mean, z_log_var, encoder_outputs])

decoder = tf.keras.Model(inputs=latent_inputs, outputs=decoder_outputs)
vae_outputs = decoder(encoder(encoder_inputs)[2])#####
vae = tf.keras.Model(inputs=encoder_inputs, outputs=vae_outputs)
# Out:
# WARNING:tensorflow:From C:\Users\HP\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\core.py:192: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.

# %% [markdown]
# ### Step 7: Define the Loss Function and Compile the Model

# %%
# Define the VAE loss within the VAE model class
class VAE(tf.keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder

    def compute_loss(self, x):
        z_mean, z_log_var, z = self.encoder(x)
        reconstructed = self.decoder(z)
        reconstruction_loss = tf.reduce_mean(
            tf.keras.losses.binary_crossentropy(x, reconstructed)
        )
        reconstruction_loss *= 28 * 28
        kl_loss = 1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var)
        kl_loss = tf.reduce_mean(kl_loss)
        kl_loss *= -0.5
        return reconstruction_loss + kl_loss

    def train_step(self, data):
        if isinstance(data, tuple):
            data = data[0]
        with tf.GradientTape() as tape:
            loss = self.compute_loss(data)
        grads = tape.gradient(loss, self.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.trainable_variables))
        return {'loss': loss}

# Instantiate and compile the VAE
vae = VAE(encoder, decoder)
vae.compile(optimizer='adam')

# %% [markdown]
# ### Step 8: Train the Model

# %%
vae.fit(x_train, x_train, epochs=num_steps, batch_size=batch_size)
# Out:
# Epoch 1/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - loss: 181.3771
# Epoch 2/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 162.4044
# Epoch 3/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 158.8854
# Epoch 4/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 156.4424
# Epoch 5/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 154.7078
# Epoch 6/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 153.4225
# Epoch 7/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 152.4014
# Epoch 8/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 151.5830
# Epoch 9/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 150.8584
# Epoch 10/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 150.2566
# Epoch 11/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 149.7215
# Epoch 12/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 149.1702
# Epoch 13/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 148.7477
# Epoch 14/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 148.2700
# Epoch 15/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 147.8815
# Epoch 16/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 147.4936
# Epoch 17/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 147.1194
# Epoch 18/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 146.8348
# Epoch 19/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 146.5776
# Epoch 20/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 146.2458
# Epoch 21/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 145.9556
# Epoch 22/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 145.7572
# Epoch 23/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 145.5194
# Epoch 24/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 145.3202
# Epoch 25/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 145.1161
# Epoch 26/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 144.8920
# Epoch 27/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 144.7134
# Epoch 28/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 144.5781
# Epoch 29/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 144.3708
# Epoch 30/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 144.1975
# Epoch 31/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 144.0437
# Epoch 32/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 143.8721
# Epoch 33/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 143.7180
# Epoch 34/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 143.5230
# Epoch 35/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 143.4445
# Epoch 36/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 143.2780
# Epoch 37/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 143.1428
# Epoch 38/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 143.0387
# Epoch 39/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 142.8622
# Epoch 40/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 142.7281
# Epoch 41/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 142.5979
# Epoch 42/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 142.5092
# Epoch 43/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 142.3642
# Epoch 44/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 142.2365
# Epoch 45/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 142.1658
# Epoch 46/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 142.0243
# Epoch 47/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 141.9557
# Epoch 48/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 141.8544
# Epoch 49/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 141.7155
# Epoch 50/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 141.6520
# Epoch 51/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 141.5265
# Epoch 52/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 141.4509
# Epoch 53/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 141.4043
# Epoch 54/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 141.3183
# Epoch 55/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 141.2116
# Epoch 56/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 141.1168
# Epoch 57/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 141.0806
# Epoch 58/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 140.9727
# Epoch 59/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 140.8962
# Epoch 60/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 140.8343
# Epoch 61/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 140.7640
# Epoch 62/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 140.7413
# Epoch 63/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 140.6383
# Epoch 64/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 140.5600
# Epoch 65/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 140.4866
# Epoch 66/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 140.4437
# Epoch 67/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 140.3863
# Epoch 68/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 140.3304
# Epoch 69/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 140.2912
# Epoch 70/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 140.1422
# Epoch 71/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 140.1623
# Epoch 72/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 140.1170
# Epoch 73/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 139.9944
# Epoch 74/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 139.9996
# Epoch 75/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 139.9461
# Epoch 76/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 139.8707
# Epoch 77/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 139.8285
# Epoch 78/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 139.8255
# Epoch 79/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 139.7342
# Epoch 80/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 139.6889
# Epoch 81/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 139.6470
# Epoch 82/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 139.5378
# Epoch 83/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 139.5681
# Epoch 84/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 139.5085
# Epoch 85/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - loss: 139.4490
# Epoch 86/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - loss: 139.3987
# Epoch 87/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 139.3799
# Epoch 88/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 139.3293
# Epoch 89/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 139.2612
# Epoch 90/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 139.2736
# Epoch 91/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 139.1855
# Epoch 92/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 139.1517
# Epoch 93/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 139.1214
# Epoch 94/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 139.0668
# Epoch 95/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 139.0277
# Epoch 96/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 139.0076
# Epoch 97/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 139.0042
# Epoch 98/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 138.9042
# Epoch 99/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 138.8678
# Epoch 100/100
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 138.8570

# %% [markdown]
# ### Step 9: Generate a Manifold of Digits

# %% [markdown]
# '''
# Generate a manifold of digits by creating a latent space grid.
# Feed these grid values into the decoder to produce images.
# '''

# %%
def generate_images(model, n_images):
    # Sample from the latent space
    random_latent_vectors = tf.random.normal(shape=(n_images, latent_dim))
    # Decode them to fake images
    generated_images = model.decoder(random_latent_vectors)
    generated_images = generated_images.numpy()

    # Calculate the number of rows needed in the subplot grid
    n_rows = int(np.ceil(n_images / 4))

    # Plot the generated images
    plt.figure(figsize=(10, 10))
    for i in range(n_images):
        plt.subplot(n_rows, 4, i + 1)
        plt.imshow(generated_images[i].reshape(28, 28), cmap='gray')
        plt.axis('off')
    plt.show()

# Generate and display images
generate_images(vae, 16)

# %% [markdown]
# ### Conclusion

# %% [markdown]
# '''
# In this demonstration, we have successfully implemented and trained a Variational Autoencoder (VAE) using TensorFlow to generate images based on the MNIST dataset. The process encompassed several critical steps, from importing necessary libraries to training the model, and finally, generating a manifold of digits.
# '''
