# %%
import torch
from transformers import pipeline
from langchain.llms import HuggingFacePipeline
from langchain.llms import HuggingFaceHub
from langchain_huggingface import HuggingFaceEndpoint
llm = HuggingFaceHub(repo_id='tiiuae/falcon-7b-instruct', huggingfacehub_api_token='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')
llm.client.api_url = 'https://api-inference.huggingface.co/models/tiiuae/falcon-7b-instruct'

# %%
from langchain.prompts import PromptTemplate
from langchain_huggingface import HuggingFaceEndpoint
from langchain.chains import SequentialChain

# %%
template = """Question: {question}

Answer: brief information."""

prompt = PromptTemplate(template=template, input_variables=["question"])

llm_chain = LLMChain(prompt=prompt, llm=llm)

# %%
question = "Tell me about Sopra steria company"

response = llm_chain.run(question)
print(response)
# Out:
# Question: Tell me about Sopra steria company
#
# Answer: brief information.
# Sopra steria is a French IT consulting and software development company. It provides services in the areas of application development, business intelligence, data management, and cloud services. The company has a presence in more than 20 countries and has over 5,000 employees.

# %%
template = """Question: {question}

Answer: Let's think step by step."""

prompt = PromptTemplate(template=template, input_variables=["question"])

llm_chain = LLMChain(prompt=prompt, llm=llm)

# %%
question = "What is quantum computing and why is it important?"

response = llm_chain.run(question)
print(response)
# Out:
# Question: What is quantum computing and why is it important?
#
# Answer: Let's think step by step.
#
# 1. Quantum computing is a field of computing that uses quantum-mechanical phenomena, such as superposition and entanglement, to perform operations on data.
#
# 2. These phenomena allow quantum computers to process data at a much faster rate than traditional computers.
#
# 3. This is important because it can lead to breakthroughs in fields such as cryptography, drug discovery, and artificial intelligence.
#
# 4. Quantum computing has the potential to revolutionize the way we process and analyze

# %%
question = "What is quantum computing and why is it important?"

response = llm_chain.run(question)
print(response)
# Out:
# Question: What is quantum computing and why is it important?
#
# Answer: brief information.
#
# Quantum computing is a type of computing that uses quantum-mechanical phenomena, such as superposition and entanglement, to perform operations on data. It is important because it can solve complex problems that are difficult or impossible to solve using classical computing.
#
# For example, quantum computing can be used to develop new drugs, simulate complex physical systems, and develop new cryptographic algorithms. It can also be used to develop new technologies, such as quantum networks, that can revolutionize the

# %%
question = "who is sachin ramesh tendulkar"

response = llm_chain.run(question)
print(response)
# Out:
# Question: who is sachin ramesh tendulkar
#
# Answer: brief information.
# Sachin Ramesh Tendulkar is a former Indian cricketer who played in the Indian Premier League. He is considered one of the greatest cricketers of all time.
